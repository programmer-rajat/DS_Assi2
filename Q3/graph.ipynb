# %%
import sys
import os
import matplotlib.pyplot as plt

# %%
#run this command
# cat input.txt
# os.system('echo 100 | ./mapper.py | sort | ./reducer.py')
for i in range(10,5000,5):
    os.system('echo '+str(i)+' | ./mapper.py | sort | ./reducer.py > tmp.txt')
    mline=0
    with open('tmp.txt','r') as f:
        for line in f:
            line = line.strip()
            # print(line)
            line = float(line)
            # mline = max(line,mline)
            #print line graph with blank y axis
            # plt.plot(i,line,'ro')
            # plt.scatter(i,line)
            #decreae dot size
            plt.scatter(i,line,s=0.1)
